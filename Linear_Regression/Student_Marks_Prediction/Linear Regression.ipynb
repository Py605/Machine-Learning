# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("student_info.csv")

# %%
data.head()
data.shape
# Out:
# (200, 2)

# %%
# Removing null values...
df = pd.DataFrame(data)
df1 = df.dropna()
df1.shape
# Out:
# (195, 2)

# %%
data.plot(x = "Hours" , y = "Scores", style='o')
plt.title("Hours Vs Scores")
plt.ylabel("Scores")
plt.xlabel("Hours")
plt.show()

# %%
# Here, dividing the data into "attributes" (inputs) and "labels" (outputs)
X = df1.iloc[:,:-1].values
y = df1.iloc[:,1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                            test_size=0.1, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,y_train)
print("Completed..")
# Out:
# Completed..

# %%
# Plotting for the Test data

# %%
line = regressor.coef_ * X + regressor.intercept_
plt.scatter(X,y)
plt.plot(X,line)
plt.show()

# %%
#Predicting the Scores
print(X_test)
y_pred = regressor.predict(X_test)
# Out:
# [[5.63]
#  [7.9 ]
#  [7.1 ]
#  [5.4 ]
#  [5.39]
#  [8.71]
#  [5.07]
#  [6.38]
#  [5.11]
#  [7.67]
#  [5.19]
#  [6.67]
#  [6.33]
#  [5.38]
#  [5.39]
#  [8.05]
#  [7.14]
#  [6.35]
#  [7.01]
#  [8.95]]

# %%
# Comparing Actual vs Predicted Values..]
df = pd.DataFrame({"Actual":y_test,"Predicted":y_pred})
print(df)
# Out:
#     Actual  Predicted
# 0    72.87  72.623582
# 1    80.76  81.514155
# 2    76.76  78.380913
# 3    70.34  71.722775
# 4    71.11  71.683609
# 5    85.98  84.686562
# 6    70.79  70.430313
# 7    77.01  75.560996
# 8    72.08  70.586975
# 9    80.58  80.613348
# 10   70.66  70.900299
# 11   76.99  76.696796
# 12   74.49  75.365168
# 13   71.94  71.644444
# 14   73.02  71.683609
# 15   79.63  82.101637
# 16   77.65  78.537575
# 17   76.19  75.443499
# 18   77.46  78.028423
# 19   85.15  85.626534

# %%
# Testin with 9.25 hours...
hours = [[9.25]]
own_pred = regressor.predict(hours)
print("No of Hours = {}".format(hours))
print("Predicted Score = {}".format(own_pred[0]))
# Out:
# No of Hours = [[9.25]]
# Predicted Score = 86.80149956927107

# %%
# calculating mean absolute error
from sklearn import metrics  
print('Mean Absolute Error:', 
      metrics.mean_absolute_error(y_test, y_pred))
# Out:
# Mean Absolute Error: 0.8698830802909697
